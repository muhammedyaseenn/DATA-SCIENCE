# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammedyaseenn/DATA-SCIENCE/blob/main/if%2Celse%2Celif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=20
if x>=20:
   print("eligible for higher studies")
print("end of the program")
# Out:
# eligible for higher studies
# end of the program

# %%
x=15
if x<=15:
  print("less charger")
# Out:
# less charger

# %%
#if-else
x=-5
if(x>0):
  print("x is positive")
else:
  print("x is negative")
# Out:
# x is negative

# %%
temparature=30
if(temparature>0):
  print("temparature is hot")
else:
  print("temparature is cold")
# Out:
# temparature is hot

# %%
balance=int(input("enter balance:"))
withdraw=int(input("enter the withdraw amount:"))
if(balance>=withdraw):
  print("withdraw")
else:
  print("insuficient")
# Out:
# enter balance:1000
# enter the withdraw amount:200
# withdraw

# %%
score=69
if(score>=90):
  print("A Grade")
elif(score>=80):
  print("B Grade")
elif(score>=70):
  print("C Grade")
else:
  print("D Grade")
# Out:
# D Grade
