# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammedyaseenn/DATA-SCIENCE/blob/main/GAME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to number guessing game")
print("guessing the number between 1-100")

secret_number=36
for i in range(0,8):
  user_input=int(input("enter your guess :"))
  if user_input<1 or user_input>100:
    print("invalid number ! please enter the number between 1-100")
  elif user_input<secret_number:
    print("your number is lesser")
  elif user_input>secret_number:
    print("your number is higher")


  else:
    print("your guess is correct")
    print(f"congradulation you have guessed the number {secret_number} in {i} attemptes")
    break
# Out:
# welcome to number guessing game
# guessing the number between 1-100
# enter your guess :36
# your guess is correct
# congradulation you have guessed the number 36 in 0 attemptes

# %%
print("welcome to number guessing game")
print("guessing the number between 1-100")

secret_number=36
for i in range(0,7):
  user_input=int(input("enter your guess :"))
  if user_input<1 or user_input>100:
    print("invalid number ! please enter the number between 1-100")
  elif user_input<secret_number:
    print("your number is lesser")
  elif user_input>secret_number:
    print("your number is higher")


  else:
    print("your guess is correct")
    print(f"congradulation you have guessed the number {secret_number} in {i} attemptes")
    break
else:
  print("your attempts are over try again later")
# Out:
# welcome to number guessing game
# guessing the number between 1-100
# enter your guess :60
# your number is higher
# enter your guess :101
# invalid number ! please enter the number between 1-100
# enter your guess :60
# your number is higher
# enter your guess :40
# your number is higher
# enter your guess :45
# your number is higher
# enter your guess :30
# your number is lesser
# enter your guess :35
# your number is lesser
# your attempts are over try again later

# %%
import random
print("welcome to number guessing game")
print("guessing the number between 1-100")

secret_number=random.randint(1,100)
for i in range(0,8):
  user_input=int(input("enter your guess :"))
  if user_input<1 or user_input>100:
    print("invalid number ! please enter the number between 1-100")
  elif user_input<secret_number:
    print("your number is lesser")
  elif user_input>secret_number:
    print("your number is higher")


  else:
    print("your guess is correct")
    print(f"congradulation you have guessed the number {secret_number} in {i} attemptes")
    break
else:
  print("your attempts are over try again later")
# Out:
# welcome to number guessing game
# guessing the number between 1-100
# enter your guess :56
# your number is higher
# enter your guess :36
# your number is higher
# enter your guess :26
# your number is higher
# enter your guess :16
# your number is lesser
# enter your guess :20
# your number is higher
# enter your guess :18
# your number is lesser
# enter your guess :19
# your guess is correct
# congradulation you have guessed the number 19 in 6 attemptes

# %%
import random
print("welcome to the game")
user_input=input("select stone,paper and scissor :")
a=["stone","paper","scissor"]
if user_input not in a:
  print("you entered invalid word")
computer_choice=random.choice(a)
print("user_input:",user_input)
print("computer choice:",computer_choice)
if user_input == computer_choice:
  print("draw try again")
elif(user_input=="paper" and computer_choice=="stone")or\
(user_input=="stone" and computer_choice=="scissor")or\
(user_input=="scissor" and computer_choice=="paper"):
  print("you won")
else:
  print("computer won")
# Out:
# welcome to the game
# select stone,paper and scissorstone
# user_input: stone
# computer choice: scissor
# you won

# %%
import random
print("welcome to the game")
user_input=input("select stone,paper and scissor :")
a=["stone","paper","scissor"]


if user_input not in a:
  print("you entered invalid word")
computer_choice=random.choice(a)
print("user_input:",user_input)
print("computer choice:",computer_choice)

if user_input == computer_choice:
  print("draw try again")
elif(user_input=="paper" and computer_choice=="stone")or\
(user_input=="stone" and computer_choice=="scissor")or\
(user_input=="scissor" and computer_choice=="paper"):
  print("you won")
else:
  print("computer win")


  play_again=input("if you want to try again or exit (yes/no)")
  if play-again!="yes":
       print("thanks for playing")
       break
except Expetation as a:
  print("an error occur:",e)
# Out:
#   File "/tmp/ipykernel_2940/2540509966.py", line 27
#     except Expetation as a:
#     ^
# SyntaxError: invalid syntax
