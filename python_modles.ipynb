# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammedyaseenn/DATA-SCIENCE/blob/main/python_modles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#bulit-in module
#math
import math
print(math.sqrt(5))
# Out:
# 2.23606797749979

# %%
#datetime
import datetime

now=datetime.datetime.now()
print(now)
# Out:
# 2026-02-07 05:12:13.582308

# %%
#sys
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
#math
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import os
print("CWD:",os.getcwd())
print("files in /content:")
print(os.listdir('/content'))
# Out:
# CWD: /content
# files in /content:
# ['.config', 'sample_data']

# %%
#create and write to a file
f=open("sample.txt","w")
f.write("Hello,this is a file created google colab!")
f.close()

# %%
#To read
f = open("sample.txt","r")
content = f.read()
print(content)
f.close()
# Out:
# Hello,this is a file created google colab!

# %%
f = open("sample.txt","a")
f.write("\nThis line is added using append mode." )
f.close()
